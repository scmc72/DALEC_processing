# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import dalecLoad

# %% [markdown]
# ## 19th May Data
#
# This data was collected on the 19th May 2022 from the jetty on airthrey loch during a cyanobacterial bloom. A corresponding water sample was taken which will be analysed later this month I think. Pauliina has already analysed the absorbance spectra of the sample using her hyperspectral camera

# %%
# let's load some of the data (LOG-45)

log45 = dalecLoad.load_DALEC_log('data/LOG_0045.dtf')

log45 # we see that log45 contains some saturated data! (I think this must have been before I turned on auto integration time)
# Out:
#                    spectral_ind     Temp  GPS_Fix          Lon  \
# Sample #  Channel
# 0        Ed                  21  21.9375        A  -3.92366170
#          Ed                  22  21.9375        A  -3.92366170
#          Ed                  23  21.9375        A  -3.92366170
#          Ed                  24  21.9375        A  -3.92366170
#          Ed                  25  21.9375        A  -3.92366170
# ...                         ...      ...      ...          ...
# 9        Lu                 216  21.9375        A  -3.92366170
#          Lu                 217  21.9375        A  -3.92366170
#          Lu                 218  21.9375        A  -3.92366170
#          Lu                 219  21.9375        A  -3.92366170
#          Lu                 220  21.9375        A  -3.92366170
#
#                    Saturation Flag  Gearpos  Solar Azi  Voltage    UTC Date  \
# Sample #  Channel
# 0        Ed                      1     27.3      219.5     12.1  19/05/2022
#          Ed                      1     27.3      219.5     12.1  19/05/2022
#          Ed                      1     27.3      219.5     12.1  19/05/2022
#          Ed                      1     27.3      219.5     12.1  19/05/2022
#          Ed                      1     27.3      219.5     12.1  19/05/2022
# ...                            ...      ...        ...      ...         ...
# 9        Lu                      0    -95.1      219.5     11.5  19/05/2022
#          Lu                      0    -95.1      219.5     11.5  19/05/2022
#          Lu                      0    -95.1      219.5     11.5  19/05/2022
#          Lu                      0    -95.1      219.5     11.5  19/05/2022
#          Lu                      0    -95.1      219.5     11.5  19/05/2022
#
#                    Roll  Solar Elev  Integration Time   Relaz      UTC Time  \
# Sample #  Channel
# 0        Ed        -1.0        48.5               256     0.0  13:54:23.521
#          Ed        -1.0        48.5               256     0.0  13:54:23.521
#          Ed        -1.0        48.5               256     0.0  13:54:23.521
#          Ed        -1.0        48.5               256     0.0  13:54:23.521
#          Ed        -1.0        48.5               256     0.0  13:54:23.521
# ...                 ...         ...               ...     ...           ...
# 9        Lu         1.0        48.5                33  -133.5  13:54:43.787
#          Lu         1.0        48.5                33  -133.5  13:54:43.787
#          Lu         1.0        48.5                33  -133.5  13:54:43.787
#          Lu         1.0        48.5                33  -133.5  13:54:43.787
#          Lu         1.0        48.5                33  -133.5  13:54:43.787
#
#                    Pitch         Lat  Heading  Spectral Magnitude
# Sample #  Channel
# 0        Ed          0.0  56.1472625    203.1            0.469311
#          Ed          0.0  56.1472625    203.1            0.486088
#          Ed          0.0  56.1472625    203.1            0.487444
#          Ed          0.0  56.1472625    203.1            0.471825
#          Ed          0.0  56.1472625    203.1            0.477817
# ...                  ...         ...      ...                 ...
# 9        Lu          0.0  56.1472549     86.0            0.013730
#          Lu          0.0  56.1472549     86.0            0.014789
#          Lu          0.0  56.1472549     86.0            0.014182
#          Lu          0.0  56.1472549     86.0            0.013085
#          Lu          0.0  56.1472549     86.0            0.013187
#
# [13800 rows x 18 columns]

# %%
# let's load some other data:

log46 = dalecLoad.load_DALEC_log('data/LOG_0046.dtf')

log46 # looks like the data isn't saturated here
# Out:
#                    spectral_ind     Temp  GPS_Fix          Lon  \
# Sample #  Channel
# 0        Ed                  21   22.375        A  -3.92365341
#          Ed                  22   22.375        A  -3.92365341
#          Ed                  23   22.375        A  -3.92365341
#          Ed                  24   22.375        A  -3.92365341
#          Ed                  25   22.375        A  -3.92365341
# ...                         ...      ...      ...          ...
# 9        Lu                 216  22.3125        A  -3.92365169
#          Lu                 217  22.3125        A  -3.92365169
#          Lu                 218  22.3125        A  -3.92365169
#          Lu                 219  22.3125        A  -3.92365169
#          Lu                 220  22.3125        A  -3.92365169
#
#                    Saturation Flag  Gearpos  Solar Azi  Voltage    UTC Date  \
# Sample #  Channel
# 0        Ed                      0    -68.8      220.1     11.6  19/05/2022
#          Ed                      0    -68.8      220.1     11.6  19/05/2022
#          Ed                      0    -68.8      220.1     11.6  19/05/2022
#          Ed                      0    -68.8      220.1     11.6  19/05/2022
#          Ed                      0    -68.8      220.1     11.6  19/05/2022
# ...                            ...      ...        ...      ...         ...
# 9        Lu                      0    -68.6      220.2     11.5  19/05/2022
#          Lu                      0    -68.6      220.2     11.5  19/05/2022
#          Lu                      0    -68.6      220.2     11.5  19/05/2022
#          Lu                      0    -68.6      220.2     11.5  19/05/2022
#          Lu                      0    -68.6      220.2     11.5  19/05/2022
#
#                    Roll  Solar Elev  Integration Time   Relaz      UTC Time  \
# Sample #  Channel
# 0        Ed         1.0        48.3                16  -133.7  13:56:25.628
#          Ed         1.0        48.3                16  -133.7  13:56:25.628
#          Ed         1.0        48.3                16  -133.7  13:56:25.628
#          Ed         1.0        48.3                16  -133.7  13:56:25.628
#          Ed         1.0        48.3                16  -133.7  13:56:25.628
# ...                 ...         ...               ...     ...           ...
# 9        Lu         0.0        48.3                85  -109.1  13:56:41.919
#          Lu         0.0        48.3                85  -109.1  13:56:41.919
#          Lu         0.0        48.3                85  -109.1  13:56:41.919
#          Lu         0.0        48.3                85  -109.1  13:56:41.919
#          Lu         0.0        48.3                85  -109.1  13:56:41.919
#
#                    Pitch         Lat  Heading  Spectral Magnitude
# Sample #  Channel
# 0        Ed          0.0  56.1472434     86.0            0.446903
#          Ed          0.0  56.1472434     86.0            0.464480
#          Ed          0.0  56.1472434     86.0            0.465030
#          Ed          0.0  56.1472434     86.0            0.450669
#          Ed          0.0  56.1472434     86.0            0.456452
# ...                  ...         ...      ...                 ...
# 9        Lu         -1.0  56.1472396    111.1            0.000665
#          Lu         -1.0  56.1472396    111.1            0.000039
#          Lu         -1.0  56.1472396    111.1            0.000303
#          Lu         -1.0  56.1472396    111.1            0.000605
#          Lu         -1.0  56.1472396    111.1            0.000831
#
# [51000 rows x 18 columns]

# %%
log47 = dalecLoad.load_DALEC_log('data/LOG_0047.dtf')

log47 # looks like the data isn't saturated here either
# Out:
#                    spectral_ind    Temp  GPS_Fix          Lon  \
# Sample #  Channel
# 0        Ed                  21  23.875        A  -3.92362995
#          Ed                  22  23.875        A  -3.92362995
#          Ed                  23  23.875        A  -3.92362995
#          Ed                  24  23.875        A  -3.92362995
#          Ed                  25  23.875        A  -3.92362995
# ...                         ...     ...      ...          ...
# 9        Lu                 216   23.25        A  -3.92363166
#          Lu                 217   23.25        A  -3.92363166
#          Lu                 218   23.25        A  -3.92363166
#          Lu                 219   23.25        A  -3.92363166
#          Lu                 220   23.25        A  -3.92363166
#
#                    Saturation Flag  Gearpos  Solar Azi  Voltage    UTC Date  \
# Sample #  Channel
# 0        Ed                      0    -61.5      221.4     11.7  19/05/2022
#          Ed                      0    -61.5      221.4     11.7  19/05/2022
#          Ed                      0    -61.5      221.4     11.7  19/05/2022
#          Ed                      0    -61.5      221.4     11.7  19/05/2022
#          Ed                      0    -61.5      221.4     11.7  19/05/2022
# ...                            ...      ...        ...      ...         ...
# 9        Lu                      0    -61.4      221.5     11.5  19/05/2022
#          Lu                      0    -61.4      221.5     11.5  19/05/2022
#          Lu                      0    -61.4      221.5     11.5  19/05/2022
#          Lu                      0    -61.4      221.5     11.5  19/05/2022
#          Lu                      0    -61.4      221.5     11.5  19/05/2022
#
#                    Roll  Solar Elev  Integration Time   Relaz      UTC Time  \
# Sample #  Channel
# 0        Ed         0.0        48.0                15  -109.9  14:00:24.298
#          Ed         0.0        48.0                15  -109.9  14:00:24.298
#          Ed         0.0        48.0                15  -109.9  14:00:24.298
#          Ed         0.0        48.0                15  -109.9  14:00:24.298
#          Ed         0.0        48.0                15  -109.9  14:00:24.298
# ...                 ...         ...               ...     ...           ...
# 9        Lu         0.0        48.0                91  -103.7  14:00:41.845
#          Lu         0.0        48.0                91  -103.7  14:00:41.845
#          Lu         0.0        48.0                91  -103.7  14:00:41.845
#          Lu         0.0        48.0                91  -103.7  14:00:41.845
#          Lu         0.0        48.0                91  -103.7  14:00:41.845
#
#                    Pitch         Lat  Heading  Spectral Magnitude
# Sample #  Channel
# 0        Ed          0.0  56.1472663    111.1            0.407124
#          Ed          0.0  56.1472663    111.1            0.422275
#          Ed          0.0  56.1472663    111.1            0.422073
#          Ed          0.0  56.1472663    111.1            0.407119
#          Ed          0.0  56.1472663    111.1            0.412930
# ...                  ...         ...      ...                 ...
# 9        Lu          0.0  56.1472473    117.8            0.001604
#          Lu          0.0  56.1472473    117.8            0.001997
#          Lu          0.0  56.1472473    117.8            0.001861
#          Lu          0.0  56.1472473    117.8            0.001844
#          Lu          0.0  56.1472473    117.8            0.001813
#
# [51000 rows x 18 columns]

# %%
# let's plot the spectra of a specific sample:

spect_wavelengths = dalecLoad.load_DALEC_spect_wavelengths('data/LOG_0046.dtf')

sample_10 = log46.loc['10', :]
Lu_10 = dalecLoad.uniform_grid_spectra(sample_10, spect_wavelengths, param='Lu')
Lsky_10 = dalecLoad.uniform_grid_spectra(sample_10, spect_wavelengths, param='Lsky')
Ed_10 = dalecLoad.uniform_grid_spectra(sample_10, spect_wavelengths, param='Ed')

# very simple Rrs calculation
RHO = 0.028
Rrs_10 = (Lu_10[:, 1] - (RHO * Lsky_10[:, 1])) / Ed_10[:, 1]

# %%
fig, ax = plt.subplots(1, 1, figsize=[12, 6])

ax.plot(Lu_10[:, 0], Rrs_10)

ax.plot([620, 620], [0.02, -0.00], '--', label='Phycocyanin (620nm)')
ax.plot([680, 680], [0.02, -0.00], '--', label='Chl-a (680nm)')
ax.plot([440, 440], [0.02, -0.00], '--', label='Chl-a (440nm)')

ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('$R_{rs} (sr^{-1}$)')
ax.grid()


plt.legend()
plt.show()

# %%
# let's plot the inverse of remote sensing reflectance!

fig, ax = plt.subplots(1, 1, figsize=[12, 6])

ax.plot(Lu_10[:, 0], 1/Rrs_10)


ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('$1 / R_{rs} (sr$)')
ax.grid()

ax.set_ylim(0, 250)
ax.set_xlim(400, 900)

plt.show()
# Out:
# No handles with labels found to put in legend.
