# %%
import pandas as pd

# %%
# what we want is to read a lgofile with multiple logs in it

df = pd.read_csv('data/21-jun-22/TESTLOG_20220622.dtf',
                 header=216,
                 parse_dates=True,
                 dayfirst=True,
                 infer_datetime_format=True,
                )

# %%
df
# Out:
#                                Sample #    UTC Date      UTC Time  GPS_Fix  \
# 0    OUTPUT LOG_0063.TXT DATA TO SCREEN         NaN           NaN      NaN
# 1            FILESIZE (Bytes)=180563.00         NaN           NaN      NaN
# 2                 In-situ Marine Optics         NaN           NaN      NaN
# 3                       DALEC (SN:0005)         NaN           NaN      NaN
# 4                    FIRMWARE: DALEC_V5         NaN           NaN      NaN
# ..                                  ...         ...           ...      ...
# 424                                  39  21/06/2022  09:31:07.030        A
# 425                                  40  21/06/2022  09:31:09.034        A
# 426                                  40  21/06/2022  09:31:09.034        A
# 427                                  40  21/06/2022  09:31:09.034        A
# 428                         END OF FILE         NaN           NaN      NaN
#
#             Lat          Lon  Solar Azi  Solar Elev  Relaz  Heading  ...  \
# 0           NaN          NaN        NaN         NaN    NaN      NaN  ...
# 1           NaN          NaN        NaN         NaN    NaN      NaN  ...
# 2           NaN          NaN        NaN         NaN    NaN      NaN  ...
# 3           NaN          NaN        NaN         NaN    NaN      NaN  ...
# 4           NaN          NaN        NaN         NaN    NaN      NaN  ...
# ..          ...          ...        ...         ...    ...      ...  ...
# 424  56.0810852  -3.99958496      120.8        46.3   85.5    206.3  ...
# 425  56.0803718  -3.99969673      120.8        46.3   85.8    206.6  ...
# 426  56.0803718  -3.99969673      120.8        46.3   85.8    206.6  ...
# 427  56.0803718  -3.99969673      120.8        46.3   85.8    206.6  ...
# 428         NaN          NaN        NaN         NaN    NaN      NaN  ...
#
#      Spec[211]  Spec[212]  Spec[213]  Spec[214]  Spec[215]  Spec[216]  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 424   0.082830   0.081549   0.082379   0.078895   0.080422   0.075147
# 425   0.169215   0.164241   0.160928   0.160912   0.160965   0.156963
# 426   0.001824   0.001803   0.001717   0.001706   0.001689   0.001686
# 427   0.084119   0.083355   0.082970   0.077099   0.080059   0.078177
# 428        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Spec[217]  Spec[218]  Spec[219]  Spec[220]
# 0          NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...
# 424   0.074971   0.075330   0.073814   0.074468
# 425   0.151662   0.145298   0.145111   0.138846
# 426   0.001616   0.001545   0.001487   0.001535
# 427   0.072079   0.073553   0.074060   0.078654
# 428        NaN        NaN        NaN        NaN
#
# [429 rows x 218 columns]

# %%
df['Sample #']

# here we're choosing a line to delineate between different log files
# perhaps could generalise this with 'END OF FILE' or something (a task for another day!)

table_names = ['OUTPUT LOG_0063.TXT DATA TO SCREEN',
               'OUTPUT LOG_0062.TXT DATA TO SCREEN',
               'OUTPUT LOG_0061.TXT DATA TO SCREEN']

groups = df['Sample #'].isin(table_names).cumsum()
# produces a dictionary with keys as the table names and values as the subtables.
# see https://stackoverflow.com/questions/34184841/python-pandas-read-csv-file-containing-multiple-tables
tables = {g.iloc[0,0]: g.iloc[1:] for k,g in df.groupby(groups)}

# %%
# let's try to generalise this

groups = df['Sample #'].isin(['DALEC (SN:0005)']).cumsum()
names = ['Log ' + str(i) for i in range(len(set(groups)))] 
tables = {name: g[1].iloc[1:] for g,name in zip(df.groupby(groups), names)} 
# because we've used 'DALEC (SN:0005)' as the way to seperate logfiles, we need to remove the first lines before this
tables.pop('Log 0')
# Out:
#                      Sample #  UTC Date  UTC Time  GPS_Fix  Lat  Lon  \
# 1  FILESIZE (Bytes)=180563.00       NaN       NaN      NaN  NaN  NaN
# 2       In-situ Marine Optics       NaN       NaN      NaN  NaN  NaN
#
#    Solar Azi  Solar Elev  Relaz  Heading  ...  Spec[211]  Spec[212]  \
# 1        NaN         NaN    NaN      NaN  ...        NaN        NaN
# 2        NaN         NaN    NaN      NaN  ...        NaN        NaN
#
#    Spec[213]  Spec[214]  Spec[215]  Spec[216]  Spec[217]  Spec[218]  \
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Spec[219]  Spec[220]
# 1        NaN        NaN
# 2        NaN        NaN
#
# [2 rows x 218 columns]

# %%
list(tables)

for k,v in tables.items():
    print("table:", k)
    print(v)
    print()
# Out:
# table: Log 0
#                    spectral_ind  Heading  Pitch  Relaz         Lat  Gearpos  \
# Sample #  Channel
# 0        Ed                  21      0.0    0.0    NaN         NaN     -0.1
#          Ed                  22      0.0    0.0    NaN         NaN     -0.1
#          Ed                  23      0.0    0.0    NaN         NaN     -0.1
#          Ed                  24      0.0    0.0    NaN         NaN     -0.1
#          Ed                  25      0.0    0.0    NaN         NaN     -0.1
# ...                         ...      ...    ...    ...         ...      ...
# 40       Lu                 216    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 217    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 218    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 219    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 220    204.9    5.0   25.3  56.0295791      0.0
#
#                    Integration Time     Temp  Saturation Flag          Lon  \
# Sample #  Channel
# 0        Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
# ...                             ...      ...              ...          ...
# 40       Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#
#                    Solar Azi  Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 0        Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
# ...                      ...   ...         ...         ...      ...      ...
# 40       Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 0        Ed        12:10:39.607            0.221737
#          Ed        12:10:39.607            0.230307
#          Ed        12:10:39.607            0.230269
#          Ed        12:10:39.607            0.222467
#          Ed        12:10:39.607            0.224349
# ...                         ...                 ...
# 40       Lu        12:11:59.031            0.001691
#          Lu        12:11:59.031            0.001588
#          Lu        12:11:59.031            0.001711
#          Lu        12:11:59.031            0.001530
#          Lu        12:11:59.031            0.001499
#
# [24600 rows x 18 columns]
#
# table: Log 1
#                    spectral_ind  Heading  Pitch  Relaz  Lat  Gearpos  \
# Sample #  Channel
# 0        Ed                  21      0.0    0.0    NaN  NaN     -0.1
#          Ed                  22      0.0    0.0    NaN  NaN     -0.1
#          Ed                  23      0.0    0.0    NaN  NaN     -0.1
#          Ed                  24      0.0    0.0    NaN  NaN     -0.1
#          Ed                  25      0.0    0.0    NaN  NaN     -0.1
# ...                         ...      ...    ...    ...  ...      ...
# 24       Lu                 216    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 217    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 218    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 219    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 220    229.9   -1.0    NaN  NaN     -0.1
#
#                    Integration Time    Temp  Saturation Flag  Lon  Solar Azi  \
# Sample #  Channel
# 0        Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
# ...                             ...     ...              ...  ...        ...
# 24       Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#
#                    Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 0        Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
# ...                 ...         ...         ...      ...      ...
# 24       Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 0        Ed        10:55:09.619            0.342763
#          Ed        10:55:09.619            0.356290
#          Ed        10:55:09.619            0.356068
#          Ed        10:55:09.619            0.344463
#          Ed        10:55:09.619            0.347757
# ...                         ...                 ...
# 24       Lu        10:55:57.932            0.002360
#          Lu        10:55:57.932            0.002452
#          Lu        10:55:57.932            0.002208
#          Lu        10:55:57.932            0.002087
#          Lu        10:55:57.932            0.002102
#
# [15000 rows x 18 columns]
#
# table: Log 2
#                    spectral_ind  Heading  Pitch  Relaz         Lat  Gearpos  \
# Sample #  Channel
# 0        Ed                  21      0.0    0.0    NaN         NaN     -0.1
#          Ed                  22      0.0    0.0    NaN         NaN     -0.1
#          Ed                  23      0.0    0.0    NaN         NaN     -0.1
#          Ed                  24      0.0    0.0    NaN         NaN     -0.1
#          Ed                  25      0.0    0.0    NaN         NaN     -0.1
# ...                         ...      ...    ...    ...         ...      ...
# 40       Lu                 216    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 217    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 218    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 219    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 220    206.6    0.0   85.8  56.0803718     -0.3
#
#                    Integration Time     Temp  Saturation Flag          Lon  \
# Sample #  Channel
# 0        Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
# ...                             ...      ...              ...          ...
# 40       Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#
#                    Solar Azi  Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 0        Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
# ...                      ...   ...         ...         ...      ...      ...
# 40       Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 0        Ed        09:29:47.604            0.189417
#          Ed        09:29:47.604            0.195705
#          Ed        09:29:47.604            0.194896
#          Ed        09:29:47.604            0.187647
#          Ed        09:29:47.604            0.188476
# ...                         ...                 ...
# 40       Lu        09:31:09.034            0.001686
#          Lu        09:31:09.034            0.001616
#          Lu        09:31:09.034            0.001545
#          Lu        09:31:09.034            0.001487
#          Lu        09:31:09.034            0.001535
#
# [24600 rows x 18 columns]
#
# table: Log 3
# Empty DataFrame
# Columns: [Sample #,  UTC Date,  UTC Time,  GPS_Fix,  Lat,  Lon,  Solar Azi,  Solar Elev,  Relaz,  Heading,  Pitch,  Roll,  Gearpos,  Voltage,  Temp,  Channel,  Integration Time,  Saturation Flag,  Spec[21],  Spec[22],  Spec[23],  Spec[24],  Spec[25],  Spec[26],  Spec[27],  Spec[28],  Spec[29],  Spec[30],  Spec[31],  Spec[32],  Spec[33],  Spec[34],  Spec[35],  Spec[36],  Spec[37],  Spec[38],  Spec[39],  Spec[40],  Spec[41],  Spec[42],  Spec[43],  Spec[44],  Spec[45],  Spec[46],  Spec[47],  Spec[48],  Spec[49],  Spec[50],  Spec[51],  Spec[52],  Spec[53],  Spec[54],  Spec[55],  Spec[56],  Spec[57],  Spec[58],  Spec[59],  Spec[60],  Spec[61],  Spec[62],  Spec[63],  Spec[64],  Spec[65],  Spec[66],  Spec[67],  Spec[68],  Spec[69],  Spec[70],  Spec[71],  Spec[72],  Spec[73],  Spec[74],  Spec[75],  Spec[76],  Spec[77],  Spec[78],  Spec[79],  Spec[80],  Spec[81],  Spec[82],  Spec[83],  Spec[84],  Spec[85],  Spec[86],  Spec[87],  Spec[88],  Spec[89],  Spec[90],  Spec[91],  Spec[92],  Spec[93],  Spec[94],  Spec[95],  Spec[96],  Spec[97],  Spec[98],  Spec[99],  Spec[100],  Spec[101],  Spec[102], ...]
# Index: []
#
# [0 rows x 218 columns]

# %%
# okay now, let's remove some rows which aren't actually data
df.drop(df[df[' UTC Date'].isna()].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9052/683390946.py in <module>
#       1 # okay now, let's remove some rows which aren't actually data
# ----> 2 df.drop(df[df[' UTC Date'].isna() or df[' UTC Date'] == ' UTC Date'].index, inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
for name, table in tables.items():
    # any row with invalid UTC date can be removed
    table.drop(table[table[' UTC Date'].isna()].index, inplace = True)
    # this removes the duplicated headings
    table.drop(table[table[' UTC Date'] == 'UTC Date'].index, inplace = True)
    
    # convert to long format
    # need to test that these variable names always load in this way (leading space on Spec etc.)
    table = pd.wide_to_long(table, [' Spec['], i=['Sample #', ' Channel'], j='spectral_ind', suffix='\d+]')
    table.reset_index(level=2, inplace=True) # remove spectral_ind as an index
    table['spectral_ind'] = pd.to_numeric(table['spectral_ind'].str[:-1]) # convert spectral_ind to numeric
    table.rename(columns={' Spec[': 'Spectral Magnitude'}, inplace=True)
    table = table.astype({'Spectral Magnitude': 'float64'})
    # change sample no. index to integer
    print('WARNING: some of my old code wont work with integerIndex=True - delete this line once this is sorted')
    idx = table.index
    table.index = table.index.set_levels([idx.levels[0].astype(int), idx.levels[1]])
    # sort index
    table.sort_index(inplace=True)
    tables[name] = table
# Out:
# WARNING: some of my old code wont work with integerIndex=True - delete this line once this is sorted
# WARNING: some of my old code wont work with integerIndex=True - delete this line once this is sorted
# WARNING: some of my old code wont work with integerIndex=True - delete this line once this is sorted

# %%
# check to see if that worked
for k,v in tables.items():
    print("table:", k)
    print(v)
    print()
# Out:
# table: Log 1
#                    spectral_ind  Heading  Pitch  Relaz         Lat  Gearpos  \
# Sample #  Channel
# 0        Ed                  21      0.0    0.0    NaN         NaN     -0.1
#          Ed                  22      0.0    0.0    NaN         NaN     -0.1
#          Ed                  23      0.0    0.0    NaN         NaN     -0.1
#          Ed                  24      0.0    0.0    NaN         NaN     -0.1
#          Ed                  25      0.0    0.0    NaN         NaN     -0.1
# ...                         ...      ...    ...    ...         ...      ...
# 40       Lu                 216    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 217    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 218    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 219    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 220    204.9    5.0   25.3  56.0295791      0.0
#
#                    Integration Time     Temp  Saturation Flag          Lon  \
# Sample #  Channel
# 0        Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
# ...                             ...      ...              ...          ...
# 40       Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#
#                    Solar Azi  Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 0        Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
# ...                      ...   ...         ...         ...      ...      ...
# 40       Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 0        Ed        12:10:39.607            0.221737
#          Ed        12:10:39.607            0.230307
#          Ed        12:10:39.607            0.230269
#          Ed        12:10:39.607            0.222467
#          Ed        12:10:39.607            0.224349
# ...                         ...                 ...
# 40       Lu        12:11:59.031            0.001691
#          Lu        12:11:59.031            0.001588
#          Lu        12:11:59.031            0.001711
#          Lu        12:11:59.031            0.001530
#          Lu        12:11:59.031            0.001499
#
# [24600 rows x 18 columns]
#
# table: Log 2
#                    spectral_ind  Heading  Pitch  Relaz  Lat  Gearpos  \
# Sample #  Channel
# 0        Ed                  21      0.0    0.0    NaN  NaN     -0.1
#          Ed                  22      0.0    0.0    NaN  NaN     -0.1
#          Ed                  23      0.0    0.0    NaN  NaN     -0.1
#          Ed                  24      0.0    0.0    NaN  NaN     -0.1
#          Ed                  25      0.0    0.0    NaN  NaN     -0.1
# ...                         ...      ...    ...    ...  ...      ...
# 24       Lu                 216    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 217    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 218    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 219    229.9   -1.0    NaN  NaN     -0.1
#          Lu                 220    229.9   -1.0    NaN  NaN     -0.1
#
#                    Integration Time    Temp  Saturation Flag  Lon  Solar Azi  \
# Sample #  Channel
# 0        Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
#          Ed                     256       0                1  NaN        NaN
# ...                             ...     ...              ...  ...        ...
# 24       Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#          Lu                     190  21.125                0  NaN        NaN
#
#                    Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 0        Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
#          Ed         0.0         NaN  21/06/2022        V      0.0
# ...                 ...         ...         ...      ...      ...
# 24       Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#          Lu         2.0         NaN  21/06/2022        V     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 0        Ed        10:55:09.619            0.342763
#          Ed        10:55:09.619            0.356290
#          Ed        10:55:09.619            0.356068
#          Ed        10:55:09.619            0.344463
#          Ed        10:55:09.619            0.347757
# ...                         ...                 ...
# 24       Lu        10:55:57.932            0.002360
#          Lu        10:55:57.932            0.002452
#          Lu        10:55:57.932            0.002208
#          Lu        10:55:57.932            0.002087
#          Lu        10:55:57.932            0.002102
#
# [15000 rows x 18 columns]
#
# table: Log 3
#                    spectral_ind  Heading  Pitch  Relaz         Lat  Gearpos  \
# Sample #  Channel
# 0        Ed                  21      0.0    0.0    NaN         NaN     -0.1
#          Ed                  22      0.0    0.0    NaN         NaN     -0.1
#          Ed                  23      0.0    0.0    NaN         NaN     -0.1
#          Ed                  24      0.0    0.0    NaN         NaN     -0.1
#          Ed                  25      0.0    0.0    NaN         NaN     -0.1
# ...                         ...      ...    ...    ...         ...      ...
# 40       Lu                 216    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 217    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 218    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 219    206.6    0.0   85.8  56.0803718     -0.3
#          Lu                 220    206.6    0.0   85.8  56.0803718     -0.3
#
#                    Integration Time     Temp  Saturation Flag          Lon  \
# Sample #  Channel
# 0        Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
#          Ed                     256        0                1          NaN
# ...                             ...      ...              ...          ...
# 40       Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#          Lu                     256  22.0625                0  -3.99969673
#
#                    Solar Azi  Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 0        Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
#          Ed              NaN   0.0         NaN  21/06/2022        V      0.0
# ...                      ...   ...         ...         ...      ...      ...
# 40       Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#          Lu            120.8   0.0        46.3  21/06/2022        A     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 0        Ed        09:29:47.604            0.189417
#          Ed        09:29:47.604            0.195705
#          Ed        09:29:47.604            0.194896
#          Ed        09:29:47.604            0.187647
#          Ed        09:29:47.604            0.188476
# ...                         ...                 ...
# 40       Lu        09:31:09.034            0.001686
#          Lu        09:31:09.034            0.001616
#          Lu        09:31:09.034            0.001545
#          Lu        09:31:09.034            0.001487
#          Lu        09:31:09.034            0.001535
#
# [24600 rows x 18 columns]

# %%
# now let's try to sort out the saturated values
# we want to remove any sample which has a saturated value

exTable = tables['Log 1']

ind = exTable[exTable[' Saturation Flag'] == '1'].index.get_level_values(0)
exTable.drop(ind, level=0, axis=0, inplace=True)
exTable
# Out:
#                    spectral_ind  Heading  Pitch  Relaz         Lat  Gearpos  \
# Sample #  Channel
# 5        Ed                  21    205.7    5.0    NaN         NaN      0.0
#          Ed                  22    205.7    5.0    NaN         NaN      0.0
#          Ed                  23    205.7    5.0    NaN         NaN      0.0
#          Ed                  24    205.7    5.0    NaN         NaN      0.0
#          Ed                  25    205.7    5.0    NaN         NaN      0.0
# ...                         ...      ...    ...    ...         ...      ...
# 40       Lu                 216    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 217    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 218    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 219    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 220    204.9    5.0   25.3  56.0295791      0.0
#
#                    Integration Time     Temp  Saturation Flag          Lon  \
# Sample #  Channel
# 5        Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
# ...                             ...      ...              ...          ...
# 40       Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#
#                    Solar Azi  Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 5        Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
# ...                      ...   ...         ...         ...      ...      ...
# 40       Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 5        Ed        12:10:50.108            0.231670
#          Ed        12:10:50.108            0.237858
#          Ed        12:10:50.108            0.236359
#          Ed        12:10:50.108            0.226115
#          Ed        12:10:50.108            0.227510
# ...                         ...                 ...
# 40       Lu        12:11:59.031            0.001691
#          Lu        12:11:59.031            0.001588
#          Lu        12:11:59.031            0.001711
#          Lu        12:11:59.031            0.001530
#          Lu        12:11:59.031            0.001499
#
# [21600 rows x 18 columns]

# %%
tables['Log 1']
# Out:
#                    spectral_ind  Heading  Pitch  Relaz         Lat  Gearpos  \
# Sample #  Channel
# 5        Ed                  21    205.7    5.0    NaN         NaN      0.0
#          Ed                  22    205.7    5.0    NaN         NaN      0.0
#          Ed                  23    205.7    5.0    NaN         NaN      0.0
#          Ed                  24    205.7    5.0    NaN         NaN      0.0
#          Ed                  25    205.7    5.0    NaN         NaN      0.0
# ...                         ...      ...    ...    ...         ...      ...
# 40       Lu                 216    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 217    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 218    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 219    204.9    5.0   25.3  56.0295791      0.0
#          Lu                 220    204.9    5.0   25.3  56.0295791      0.0
#
#                    Integration Time     Temp  Saturation Flag          Lon  \
# Sample #  Channel
# 5        Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
#          Ed                      42   21.375                0          NaN
# ...                             ...      ...              ...          ...
# 40       Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#          Lu                     256  21.6875                0  -4.06032180
#
#                    Solar Azi  Roll  Solar Elev    UTC Date  GPS_Fix  Voltage  \
# Sample #  Channel
# 5        Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
#          Ed              NaN   1.0         NaN  21/06/2022        V     11.5
# ...                      ...   ...         ...         ...      ...      ...
# 40       Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#          Lu            179.6   0.0        57.7  21/06/2022        A     11.5
#
#                        UTC Time  Spectral Magnitude
# Sample #  Channel
# 5        Ed        12:10:50.108            0.231670
#          Ed        12:10:50.108            0.237858
#          Ed        12:10:50.108            0.236359
#          Ed        12:10:50.108            0.226115
#          Ed        12:10:50.108            0.227510
# ...                         ...                 ...
# 40       Lu        12:11:59.031            0.001691
#          Lu        12:11:59.031            0.001588
#          Lu        12:11:59.031            0.001711
#          Lu        12:11:59.031            0.001530
#          Lu        12:11:59.031            0.001499
#
# [21600 rows x 18 columns]

# %%
pd.to_datetime(exTable[' UTC Time'], infer_datetime_format=True)
# Out:
# Sample #   Channel
# 5         Ed         2022-06-23 12:10:50.108
#           Ed         2022-06-23 12:10:50.108
#           Ed         2022-06-23 12:10:50.108
#           Ed         2022-06-23 12:10:50.108
#           Ed         2022-06-23 12:10:50.108
#                                ...
# 40        Lu         2022-06-23 12:11:59.031
#           Lu         2022-06-23 12:11:59.031
#           Lu         2022-06-23 12:11:59.031
#           Lu         2022-06-23 12:11:59.031
#           Lu         2022-06-23 12:11:59.031
# Name:  UTC Time, Length: 21600, dtype: datetime64[ns]
